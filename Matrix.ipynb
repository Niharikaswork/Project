# %% [markdown]
# In \[7\]:
#
#     #OR Gate
#     import tensorflow as tf
#     import matplotlib.pyplot as plt
#
#     #Input and Target
#
#     X = [[0.1, 0.1, 1], [0.1, 0.9, 1], [0.9, 0.1, 1], [0.9, 0.9, 1]]
#     Y = [0.1, 0.9, 0.9, 0.1]
#
#     #Model Building and Training for 100 epochs
#     train= tf.keras.models.Sequential()
#     train.add(tf.keras.layers.Dense(units=1,input_dim=3,activation='linear'))
#     train.compile(optimizer='sgd',loss='mse' )
#     history = train.fit(x=X,y=Y, epochs=100)
#
#     #Model Prediction
#     Y = train.predict(X)
#     Y
#
#
#     # summarize history for loss
#     plt.plot(history.history['loss'])
#     plt.title('model loss')
#     plt.ylabel('loss')
#     plt.xlabel('epoch')
#     plt.legend(['train'], loc='upper left')
#     plt.grid()
#     plt.show()
#
#     Epoch 1/100
#     1/1 [==============================] - 0s 108ms/step - loss: 2.2308
#     Epoch 2/100
#     1/1 [==============================] - 0s 0s/step - loss: 2.0533
#     Epoch 3/100
#     1/1 [==============================] - 0s 0s/step - loss: 1.8931
#     Epoch 4/100
#     1/1 [==============================] - 0s 8ms/step - loss: 1.7487
#     Epoch 5/100
#     1/1 [==============================] - 0s 0s/step - loss: 1.6183
#     Epoch 6/100
#     1/1 [==============================] - 0s 8ms/step - loss: 1.5007
#     Epoch 7/100
#     1/1 [==============================] - 0s 8ms/step - loss: 1.3945
#     Epoch 8/100
#     1/1 [==============================] - 0s 8ms/step - loss: 1.2986
#     Epoch 9/100
#     1/1 [==============================] - 0s 8ms/step - loss: 1.2121
#     Epoch 10/100
#     1/1 [==============================] - 0s 0s/step - loss: 1.1340
#     Epoch 11/100
#     1/1 [==============================] - 0s 0s/step - loss: 1.0634
#     Epoch 12/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.9997
#     Epoch 13/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.9421
#     Epoch 14/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.8900
#     Epoch 15/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.8430
#     Epoch 16/100
#     1/1 [==============================] - 0s 4ms/step - loss: 0.8004
#     Epoch 17/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.7619
#     Epoch 18/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.7271
#     Epoch 19/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.6955
#     Epoch 20/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.6670
#     Epoch 21/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.6411
#     Epoch 22/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.6176
#     Epoch 23/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.5963
#     Epoch 24/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.5770
#     Epoch 25/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.5594
#     Epoch 26/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.5435
#     Epoch 27/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.5290
#     Epoch 28/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.5158
#     Epoch 29/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.5037
#     Epoch 30/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.4927
#     Epoch 31/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.4827
#     Epoch 32/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.4735
#     Epoch 33/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.4651
#     Epoch 34/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.4574
#     Epoch 35/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.4503
#     Epoch 36/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.4438
#     Epoch 37/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.4378
#     Epoch 38/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.4323
#     Epoch 39/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.4272
#     Epoch 40/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.4224
#     Epoch 41/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.4180
#     Epoch 42/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.4140
#     Epoch 43/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.4102
#     Epoch 44/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.4066
#     Epoch 45/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.4033
#     Epoch 46/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.4002
#     Epoch 47/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3972
#     Epoch 48/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3945
#     Epoch 49/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3919
#     Epoch 50/100
#     1/1 [==============================] - 0s 9ms/step - loss: 0.3894
#     Epoch 51/100
#     1/1 [==============================] - 0s 12ms/step - loss: 0.3871
#     Epoch 52/100
#     1/1 [==============================] - 0s 9ms/step - loss: 0.3848
#     Epoch 53/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3827
#     Epoch 54/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3807
#     Epoch 55/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3787
#     Epoch 56/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3768
#     Epoch 57/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3750
#     Epoch 58/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3733
#     Epoch 59/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3716
#     Epoch 60/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3700
#     Epoch 61/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3684
#     Epoch 62/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3669
#     Epoch 63/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3654
#     Epoch 64/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3639
#     Epoch 65/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3625
#     Epoch 66/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3611
#     Epoch 67/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3598
#     Epoch 68/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3585
#     Epoch 69/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3571
#     Epoch 70/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3559
#     Epoch 71/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3546
#     Epoch 72/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3534
#     Epoch 73/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3521
#     Epoch 74/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3509
#     Epoch 75/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3497
#     Epoch 76/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3486
#     Epoch 77/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3474
#     Epoch 78/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3463
#     Epoch 79/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3451
#     Epoch 80/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3440
#     Epoch 81/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3429
#     Epoch 82/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3418
#     Epoch 83/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3407
#     Epoch 84/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3396
#     Epoch 85/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3386
#     Epoch 86/100
#     1/1 [==============================] - 0s 355us/step - loss: 0.3375
#     Epoch 87/100
#     1/1 [==============================] - 0s 10ms/step - loss: 0.3364
#     Epoch 88/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3354
#     Epoch 89/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3344
#     Epoch 90/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3333
#     Epoch 91/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3323
#     Epoch 92/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3313
#     Epoch 93/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3303
#     Epoch 94/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3293
#     Epoch 95/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3283
#     Epoch 96/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3273
#     Epoch 97/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.3264
#     Epoch 98/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3254
#     Epoch 99/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3244
#     Epoch 100/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.3235
#     WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000020217F16040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# ![](data:image/png;base64,...%0A)
#
# In \[8\]:
#
#     #XOR Gate
#     import tensorflow as tf
#     import matplotlib.pyplot as plt
#
#     #Input and Target
#
#     X = [[0.1, 0.1, 1], [0.1, 0.9, 1], [0.9, 0.1, 1], [0.9, 0.9, 1]]
#     Y = [0.1, 0.9, 0.9, 0.1]
#
#     #Model Building and Training for 100 epochs
#     train = tf.keras.models.Sequential()
#     train.add(tf.keras.layers.Dense(units=2,input_dim=3,activation='linear'))
#     train.add(tf.keras.layers.Dense(units=1))
#     train.compile(optimizer='sgd',loss='mse' )
#     history = train.fit(x=X,y=Y, epochs=100)
#
#
#     #Model Prediction
#
#     Y = model.predict(X)
#     Y
#
#
#     # summarize history for loss
#     plt.plot(history.history['loss'])
#     plt.title('model loss')
#     plt.ylabel('loss')
#     plt.xlabel('epoch')
#     plt.legend(['train'], loc='upper left')
#     plt.grid()
#     plt.show()
#
#     Epoch 1/100
#     1/1 [==============================] - 0s 118ms/step - loss: 0.3199
#     Epoch 2/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.2768
#     Epoch 3/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.2462
#     Epoch 4/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.2244
#     Epoch 5/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.2089
#     Epoch 6/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.1979
#     Epoch 7/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.1901
#     Epoch 8/100
#     1/1 [==============================] - 0s 8ms/step - loss: 0.1845
#     Epoch 9/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.1805
#     Epoch 10/100
#     1/1 [==============================] - 0s 0s/step - loss: 0.